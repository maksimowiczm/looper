# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import math
import json

PRECISION = 6

pd.options.display.float_format = '{:,.6f}'.format

# %% [markdown]
# 1. Wczytanie danych wyjściowych z symulacji -> `looper/simulation/results`

# %%
folder_path = '../results'

csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
dataframes = {os.path.splitext(f)[0]: pd.read_csv(os.path.join(folder_path, f)) for f in csv_files}

# %% [markdown]
# - Dodanie kolumny z wartościa szukanego optimum

# %%
with open('../functions.json', 'r') as f:
    functions_minimums = json.load(f)

for name, df in dataframes.items():
    function_name = name.split('_')[0]
    optimum_value = functions_minimums[function_name]['minimum_value']
    df['optimum'] = optimum_value

# %% [markdown]
# 2. Dla każdej kombinacji funkcji i mutacji wyliczenie **MBF**, **BBF** i **WBF**

# %%
results = {}

for name, df in dataframes.items():
    mbf = df['fitness'].mean()
    bbf = df['fitness'].min()
    wbf = df['fitness'].max()
    var = ((df['fitness'] - df['optimum']) ** 2).mean()
    std_dev = df['fitness'].std()
    results[name] = {'optimum': df['optimum'].iloc[0], 'MBF': mbf, 'BBF': bbf, 'WBF': wbf, 'STD': std_dev, 'VAR': var}

results_df = pd.DataFrame.from_dict(results, orient='index')
results_df.index = results_df.index.str.split('_', expand=True)
results_df.index.names = ['funkcja', 'mutacja']

results_df.sort_values(by=['funkcja', 'mutacja'], inplace=True)
results_df = results_df.reset_index()

results_df
# Out:
#         funkcja      mutacja   optimum                 MBF  \
# 0        ackley     best1bin  0.000000            0.011680
# 1        ackley  current2bin  0.000000           16.871396
# 2        ackley     rand1bin  0.000000            3.252276
# 3        ackley     rand2bin  0.000000           16.229213
# 4         beale     best1bin  0.000000            0.000000
# 5         beale  current2bin  0.000000            0.000291
# 6         beale     rand1bin  0.000000            0.000000
# 7         beale     rand2bin  0.000000            0.000000
# 8         booth     best1bin  0.000000            0.000000
# 9         booth  current2bin  0.000000            0.000000
# 10        booth     rand1bin  0.000000            0.000000
# 11        booth     rand2bin  0.000000            0.000000
# 12     griewank     best1bin  0.000000            0.878485
# 13     griewank  current2bin  0.000000           60.308371
# 14     griewank     rand1bin  0.000000            6.357833
# 15     griewank     rand2bin  0.000000           51.381846
# 16         levy     best1bin  0.000000            0.010658
# 17         levy  current2bin  0.000000           13.574696
# 18         levy     rand1bin  0.000000            2.530787
# 19         levy     rand2bin  0.000000           11.635893
# 20  michalewicz     best1bin -1.801300 -570,598,818.462294
# 21  michalewicz  current2bin -1.801300 -571,141,881.917970
# 22  michalewicz     rand1bin -1.801300 -571,265,632.390329
# 23  michalewicz     rand2bin -1.801300 -571,265,632.334750
# 24    rastrigin     best1bin  0.000000            4.178868
# 25    rastrigin  current2bin  0.000000           19.309538
# 26    rastrigin     rand1bin  0.000000           10.571386
# 27    rastrigin     rand2bin  0.000000           17.009628
# 28   rosenbrock     best1bin  0.000000            0.000009
# 29   rosenbrock  current2bin  0.000000           16.018060
# 30   rosenbrock     rand1bin  0.000000            0.385365
# 31   rosenbrock     rand2bin  0.000000            5.915906
# 32     schwefel     best1bin  0.000000          180.808990
# 33     schwefel  current2bin  0.000000          565.607629
# 34     schwefel     rand1bin  0.000000          279.902341
# 35     schwefel     rand2bin  0.000000          439.578224
# 36       sphere     best1bin  0.000000            0.000000
# 37       sphere  current2bin  0.000000            0.000000
# 38       sphere     rand1bin  0.000000            0.000000
# 39       sphere     rand2bin  0.000000            0.000000
#
#                    BBF                 WBF              STD  \
# 0             0.002622            0.041776         0.008480
# 1            13.807164           19.519658         1.390492
# 2             1.495672            5.042995         0.906857
# 3            13.125353           18.525595         1.495865
# 4             0.000000            0.000000         0.000000
# 5             0.000009            0.001686         0.000358
# 6             0.000000            0.000000         0.000000
# 7             0.000000            0.000000         0.000000
# 8             0.000000            0.000000         0.000000
# 9             0.000000            0.000002         0.000000
# 10            0.000000            0.000000         0.000000
# 11            0.000000            0.000000         0.000000
# 12            0.637864            1.066020         0.107197
# 13           32.757438           95.277189        14.649252
# 14            3.157958            9.739022         1.607078
# 15           25.760107           81.060811        12.469807
# 16            0.000185            0.126932         0.023811
# 17            5.142398           21.551201         3.868935
# 18            0.988125            4.785651         0.920619
# 19            3.299171           19.379525         4.015400
# 20 -571,265,632.390332 -551,261,214.549182 3,652,290.300452
# 21 -571,263,924.672430 -570,459,064.316883   178,075.848482
# 22 -571,265,632.390331 -571,265,632.390320         0.000003
# 23 -571,265,632.389143 -571,265,632.105945         0.072117
# 24            0.073567            8.998547         2.051120
# 25            8.490065           27.471902         4.189448
# 26            6.348797           16.994279         2.879098
# 27            7.167898           23.791473         4.049092
# 28            0.000000            0.000209         0.000038
# 29            3.901279           47.804967        11.135724
# 30            0.026717            0.839974         0.233181
# 31            0.699864           15.778117         3.326280
# 32          -77.138228          601.316427       180.118843
# 33          247.149797          739.685227       119.594352
# 34           72.695240          468.941461       123.476931
# 35          187.900894          662.635831       100.191604
# 36            0.000000            0.000000         0.000000
# 37            0.000000            0.000000         0.000000
# 38            0.000000            0.000000         0.000000
# 39            0.000000            0.000000         0.000000
#
#                               VAR
# 0                        0.000206
# 1                      286.513016
# 2                       11.372276
# 3                      265.550394
# 4                        0.000000
# 5                        0.000000
# 6                        0.000000
# 7                        0.000000
# 8                        0.000000
# 9                        0.000000
# 10                       0.000000
# 11                       0.000000
# 12                       0.782844
# 13                   3,844.546837
# 14                      42.918648
# 15                   2,790.406999
# 16                       0.000662
# 17                     198.742081
# 18                       7.224172
# 19                     150.979994
# 20 325,595,904,158,550,848.000000
# 21 326,203,077,877,178,816.000000
# 22 326,344,420,692,281,280.000000
# 23 326,344,420,628,780,480.000000
# 24                      21.529798
# 25                     389.824679
# 26                     119.767105
# 27                     305.176084
# 28                       0.000000
# 29                     376.449105
# 30                       0.201067
# 31                      45.693273
# 32                  64,053.261685
# 33                 333,738.038343
# 34                  93,083.654475
# 35                 202,932.760429
# 36                       0.000000
# 37                       0.000000
# 38                       0.000000
# 39                       0.000000

# %% [markdown]
# 3. Narysuj wykresy MDF, BBF, WBF w zależności od funkcji i mutacji.

# %%
functions = results_df['funkcja'].unique()

n_cols = 2
n_rows = math.ceil(len(functions) / n_cols)
fig, axes = plt.subplots(n_rows, n_cols, figsize=(8, n_rows * 3))
axes = axes.flatten()

for i, func in enumerate(functions):
    ax = axes[i]
    func_data = results_df[results_df['funkcja'] == func]
    optimum_value = func_data['optimum'].iloc[0]  # Get the optimum value for the function
    
    func_data.plot(
        x='mutacja',
        y=['MBF', 'BBF', 'WBF'],
        kind='bar',
        ax=ax,
        title=f"{func} (optimum: {optimum_value})"
    )
    ax.set_ylabel('Values')
    ax.set_xlabel('Mutation')
    ax.tick_params(axis='x', rotation=0)

# remove unused axes
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# 4.
